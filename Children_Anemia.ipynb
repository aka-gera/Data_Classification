# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pwd
# %cd /content/drive/MyDrive/ML2023/data-analysis/
# !ls

# %% [markdown]
# # **CLASSIFIER**
#
# *This algorithm will identify the optimal classification machine learning model for a given dataset.*

# %% [markdown]
# # Import the helper classes

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import math
from plotly.subplots import make_subplots

from aka_data_analysis.aka_plot import aka_plot, aka_correlation_analysis
from aka_data_analysis.aka_learning import aka_learn,aka_clean,aka_filter

aka_plot = aka_plot()
aka_corr_an = aka_correlation_analysis()
aka_clean = aka_clean()
aka_learn = aka_learn()
aka_filter = aka_filter()
aka_corr_an = aka_correlation_analysis()

# %%
import warnings
from sklearn.exceptions import FitFailedWarning
# Filter out the FitFailedWarning
warnings.filterwarnings("ignore", category=FitFailedWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import plotly.figure_factory as ff
import plotly.express as px
import numpy as np
import pandas as pd

# %% [markdown]
# # Import the dataset

# %% [markdown]
# The data is provided from: https://www.kaggle.com/datasets/adeolaadesina/factors-affecting-children-anemia-level

# %%
df = aka_clean.df_get('Children_Anemia/children anemia.csv')

# %% [markdown]
# # Clean Data

# %%
df.head(5)

# %% [markdown]
# ## Swap the target and the last feature

# %%
df = aka_clean.swap_features(df,7)
df.head()

# %% [markdown]
# ## Drop feature(s)

# %%
feat = [-3]
df = aka_clean.drop_feature(df,feat)
df.head()

# %%
df.describe()

# %% [markdown]
# ##  Convert categorical variables into numerical representations

# %%
mapping,swapMapping = aka_clean.CleaningVar(df)
df = aka_clean.CleaningDF(df,mapping)
df.head()

# %% [markdown]
# # Search for the most effective ML algorithm to learn the dataset

# %% [markdown]
# ## Choose the parameters for the searching
#
# <center>
#
#
# <font size="45">
#
# **Table of the list of machine learning algorithms to use in the search**
#
# |Keys | ML name |
# ------ |----------------------
# |LGC| Logistic Regression |
# |DTC| Decision Tree Classifier|
# |KNN| K-Nearest Neighbors |
# |SVC| Support Vector Classification |
# |GNB| Gaussian Naive Bayes |
# |SGD| Stochastic Gradient Descent |
# |ABC| AdaBoost classifier|
# |RFC| Random Forest Classifier|
# |GBC| Gradient Boosting Classifier|
#
# </font>
#
# </center>

# %%
mls = ['DTC','GNB','KNN', 'GBC', 'ABC','RFC','LGC']    # Choose the key of the Machine learning algorithm

confidence_interval_limit =   [5]            # Define the limits m of the confidence interval [-m, m] and eliminate the outliers'''

correlation_percentage_threshold = [.9]      # Set the limit of the correlation between the feature to be removed

pre_proc = 'none'                             # Choose between 'XY' to standardize both 'X' and 'Y',
                                              #                'X' to standardize only 'X',
                                              #                'Y' to standardize only 'Y',
                                              #                'none' to not standardize the dataset
disp_dash = 'all'                             # Choose between  'all' to diplay all report of the ML
                                              #                 'sup'  to display the most significant report

mach = 'adv'                                  # Choose between  'adv' to use advanced parameters in the ML model
                                              #                  'none' to use a default parameters

file_name = 'data'                            # Enter the name of the output data file for the report

file_name_scre = 0.85                        # Enter the minimum value of the ML score to be saved in the report

# %%
aka_learn.Search_ML(df,mls,mach,pre_proc,confidence_interval_limit,correlation_percentage_threshold,disp_dash,file_name,file_name_scre)

# %%
std_inter = [-3,3]
corr_per = 0.9
ml = 'DTC'
pre_proc = 'none'

clf,scre,MSE_,corr_tmp,df_,y_test,y_pred = aka_learn.ML(df,std_inter,corr_per,pre_proc,ml)

# %% [markdown]
# ## Graph the features that are highly correlated

# %%
fig = aka_corr_an.Plot_Correlate_Features(df,list(corr_tmp),400,500,1)
if fig is not None:
    fig.show()
# Out:
# Empty list is provided.

# %% [markdown]
# ## Visualize the distribution of the filtered dataset

# %%
for feat in [0,1,2]:
  df_0 = pd.DataFrame()
  df_0['true'] = df[df.columns[feat]]
  df_0['filtered'] = df_[df_.columns[feat]]
  fig = aka_plot.plot_history_all(df_0)
  fig.show()
  df_0.shape

# %% [markdown]
# ## Confusion Matrix

# %%
y_pred_ = aka_clean.swap_map(y_pred,swapMapping)
y_test_ = aka_clean.swap_map(y_test,swapMapping)
Label = [ str(un) for un in np.unique(pd.concat([y_pred_, y_test_]))]

# %%
shw = 1
fig2 =  aka_plot.plot_confusion_matrix(y_test,y_pred,Label,shw)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aba0954c-3850-4efc-9006-ed00deda34d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aba0954c-3850-4efc-9006-ed00deda34d1")) {                    Plotly.newPlot(                        "aba0954c-3850-4efc-9006-ed00deda34d1",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":true,"x":["Mild","Moderate","Not anemic","Severe"],"y":["Mild","Moderate","Not anemic","Severe"],"z":[[604,121,77,2],[82,722,44,0],[91,160,6289,0],[2,0,0,2]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"604","x":"Mild","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"121","x":"Moderate","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"77","x":"Not anemic","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"2","x":"Severe","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"82","x":"Mild","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"722","x":"Moderate","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"44","x":"Not anemic","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"Severe","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"91","x":"Mild","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"160","x":"Moderate","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"6289","x":"Not anemic","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"Severe","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"2","x":"Mild","xref":"x","y":"Severe","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"Moderate","xref":"x","y":"Severe","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"Not anemic","xref":"x","y":"Severe","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"2","x":"Severe","xref":"x","y":"Severe","yref":"y"}],"xaxis":{"dtick":1,"gridcolor":"rgb(0, 0, 0)","side":"bottom","ticks":"","title":{"text":"Predicted labels","font":{"size":14},"standoff":25}},"yaxis":{"dtick":1,"ticks":"","ticksuffix":"  ","title":{"text":"True labels","font":{"size":14},"standoff":25}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0 ...

# %% [markdown]
# ## Classification Report

# %%
shw = 1
fig3 =  aka_plot.plot_classification_report(y_test,y_pred,Label,shw)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6fa3cf65-d4a5-4bb0-a9e2-a08b54f26940" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fa3cf65-d4a5-4bb0-a9e2-a08b54f26940")) {                    Plotly.newPlot(                        "6fa3cf65-d4a5-4bb0-a9e2-a08b54f26940",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":false,"x":["precision","recall","f1-score","support"],"y":["Mild","Moderate","Not anemic","Severe"],"z":[[0.78,0.75,0.76,804.0],[0.72,0.85,0.78,848.0],[0.98,0.96,0.97,6540.0],[0.5,0.5,0.5,4.0]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.78","x":"precision","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.75","x":"recall","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.76","x":"f1-score","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"804.0","x":"support","xref":"x","y":"Mild","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.72","x":"precision","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.85","x":"recall","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.78","x":"f1-score","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"848.0","x":"support","xref":"x","y":"Moderate","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.98","x":"precision","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.96","x":"recall","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.97","x":"f1-score","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"6540.0","x":"support","xref":"x","y":"Not anemic","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.5","x":"precision","xref":"x","y":"Severe","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.5","x":"recall","xref":"x","y":"Severe","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.5","x":"f1-score","xref":"x","y":"Severe","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"4.0","x":"support","xref":"x","y":"Severe","yref":"y"}],"xaxis":{"dtick":1,"gridcolor":"rgb(0, 0, 0)","side":"top","ticks":"","title":{"font":{"size":14},"standoff":25}},"yaxis":{"dtick":1,"ticks":"","ticksuffix":"  ","title":{"font":{"size":14},"standoff":25}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0," ...
